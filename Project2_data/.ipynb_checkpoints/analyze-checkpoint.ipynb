# %%
#This is pyenv file for analyze data after making subset and AI classification

# %%
import pandas as pd
pd.set_option('display.max_columns', 50)

# %%
df_2025 = pd.read_csv('Recall_classified2025.csv')
df_2024 = pd.read_csv('Recall_classified2024.csv')
df_2005 = pd.read_csv('Recall_classified2005.csv')
df_2010 = pd.read_csv('Recall_classified2010.csv')
df_2015 = pd.read_csv('Recall_classified2015.csv')

# %%
df_2000 = pd.read_csv('Recall_classified2000.csv')

# %%
df_2020 = pd.read_csv('Recall_classified2020.csv')

# %%
df_2026 = pd.read_csv('Recall_classified2026.csv')

# %%
df_2020.head(10)
# Out:
#    Unnamed: 0  RECORD_ID     CAMPNO    MAKETXT                 MODELTXT  \
# 0           0     134691  18V902000     IC BUS                     CESB
# 1           1     135829  18V884000  BLUE BIRD        VISION SCHOOL BUS
# 2           2     135831  18V884000  BLUE BIRD        VISION SCHOOL BUS
# 3           3     136428  18V846000  BLUE BIRD  ALL AMERICAN SCHOOL BUS
# 4           4     136430  18V846000  BLUE BIRD        VISION SCHOOL BUS
# 5           5     136697  18V566000  BLUE BIRD        VISION SCHOOL BUS
# 6           6     136698  18V566000  BLUE BIRD        VISION SCHOOL BUS
# 7           7     138121  18V821000     IC BUS                     CESB
# 8           8     138201  18V885000  BLUE BIRD       VISION TRANSIT BUS
# 9           9     138202  18V885000  BLUE BIRD       VISION TRANSIT BUS
#
#    YEARTXT  MFGCAMPNO                                           COMPNAME  \
# 0     2020      18520  SERVICE BRAKES, HYDRAULIC:BRAKE FLUID LOW WARN...
# ...

# %%
df_2025.value_counts('ai_guess')
# Out:
# ai_guess
# software            4620
# electronics         1698
# others              1280
# chasies             1105
# safety_equipment     546
# powertrain           368
# Name: count, dtype: int64

# %%
df_2005.value_counts('ai_guess')
# Out:
# ai_guess
# others              1694
# safety_equipment    1074
# chasies              766
# electronics          652
# powertrain           421
# software              66
# Name: count, dtype: int64

# %%
df_2010.value_counts('ai_guess')
# Out:
# ai_guess
# safety_equipment    2009
# others              1926
# electronics         1098
# chasies              687
# powertrain           607
# software             260
# Name: count, dtype: int64

# %%
df_2015.value_counts('ai_guess')
# Out:
# ai_guess
# others              2212
# safety_equipment    1437
# electronics         1196
# chasies             1193
# powertrain           908
# software             445
# Name: count, dtype: int64

# %%
df_2025.value_counts('MFGNAME').head(20)
# Out:
# MFGNAME
# Toyota Motor Engineering & Manufacturing    3804
# PACCAR Incorporated                          741
# Ford Motor Company                           582
# Mercedes-Benz USA, LLC                       447
# Daimler Trucks North America, LLC            433
# Honda (American Honda Motor Co.)             270
# New Flyer of America, Inc.                   225
# Hyundai Motor America                        221
# Forest River, Inc.                           186
# Nissan North America, Inc.                   182
# BMW of North America, LLC                    131
# Chrysler (FCA US, LLC)                       126
# GEM WAEV LLC                                 108
# Kia America, Inc.                            104
# Volkswagen Group of America, Inc.             93
# International Motors, LLC                     89
# Keystone RV Company                           86
# Prevost Car (US) Inc.                         84
# Altec Industries, Inc.                        76
# ...

# %%
df_2025.shape
# Out:
# (9617, 31)

# %%
df_2025[(df_2025['MFGNAME']=="Toyota Motor Engineering & Manufacturing")&(df_2025['ai_guess']=="software")].head(30)
# Out:
#       Unnamed: 0  RECORD_ID     CAMPNO MAKETXT        MODELTXT  YEARTXT  \
# 607          607     268905  24V708000  TOYOTA  COROLLA HYBRID     2025
# 608          608     268906  24V708000  TOYOTA  COROLLA HYBRID     2025
# 609          609     268907  24V708000  TOYOTA  COROLLA HYBRID     2025
# 610          610     268908  24V708000  TOYOTA  COROLLA HYBRID     2025
# 611          611     268909  24V708000  TOYOTA  COROLLA HYBRID     2025
# 612          612     268910  24V708000  TOYOTA  COROLLA HYBRID     2025
# 613          613     268911  24V708000  TOYOTA  COROLLA HYBRID     2025
# 614          614     268912  24V708000  TOYOTA  COROLLA HYBRID     2025
# 615          615     268913  24V708000  TOYOTA  COROLLA HYBRID     2025
# 616          616     268914  24V708000  TOYOTA  COROLLA HYBRID     2025
# 1854        1854     291802  25V577000   LEXUS              RZ     2025
# 1859        1859     291807  25V577000   LEXUS              RZ     2025
# ...

# %%
df_2025.value_counts('COMPNAME').head(10)
# Out:
# COMPNAME
# BACK OVER PREVENTION:DISPLAY FUNCTION                                                                               2460
# ELECTRICAL SYSTEM: INSTRUMENT CLUSTER/PANEL                                                                         1365
# ELECTRICAL SYSTEM:SOFTWARE                                                                                           300
# SERVICE BRAKES, HYDRAULIC:ANTILOCK/TRACTION CONTROL/ELECTRONIC LIMITED SLIP:CONTROL UNIT/MODULE                      233
# BACK OVER PREVENTION:SOFTWARE                                                                                        212
# STEERING:LINKAGES:TIE ROD ASSEMBLY                                                                                   185
# STEERING                                                                                                             157
# ELECTRICAL SYSTEM:PROPULSION SYSTEM:TRACTION BATTERY:MANAGEMENT SYSTEM/ENERGY CONTROL MODULE (BMS/BECM):SOFTWARE     156
# ...

# %%
df_2025_ai=df_2025.value_counts('ai_guess')

# %%
df_2025_ai=df_2025_ai.reset_index()

# %%
df_2025_ai.to_csv('2025_ai.csv',index=False)

# %%
df_2025[df_2025['ai_guess']=="software"].value_counts('COMPNAME').head(30)
# Out:
# COMPNAME
# BACK OVER PREVENTION:DISPLAY FUNCTION                                                                               2453
# ELECTRICAL SYSTEM: INSTRUMENT CLUSTER/PANEL                                                                         1252
# ELECTRICAL SYSTEM:PROPULSION SYSTEM:TRACTION BATTERY:MANAGEMENT SYSTEM/ENERGY CONTROL MODULE (BMS/BECM):SOFTWARE     156
# BACK OVER PREVENTION:SOFTWARE                                                                                        120
# BACK OVER PREVENTION:WARNINGS:EXTERNAL/PEDESTRIAN ALERT                                                               85
# ELECTRICAL SYSTEM:SOFTWARE                                                                                            53
# FORWARD COLLISION AVOIDANCE: AUTOMATIC EMERGENCY BRAKING                                                              50
# ELECTRICAL SYSTEM:PROPULSION SYSTEM:TRACTION BATTERY                                                                  43
# ...

# %%
df_2015[(df_2015['PARK_IT']=="Yes")].value_counts('ai_guess')
# Out:
# ai_guess
# chasies             21
# powertrain          10
# others               6
# safety_equipment     4
# electronics          2
# Name: count, dtype: int64

# %%
df_2005[(df_2005['PARK_IT']=="Yes")].value_counts('ai_guess')
# Out:
# ai_guess
# safety_equipment    43
# others               6
# chasies              4
# Name: count, dtype: int64

# %%
df_2025[df_2025['COMPNAME']=="ELECTRICAL SYSTEM:PROPULSION SYSTEM:TRACTION BATTERY:MANAGEMENT SYSTEM/ENERGY CONTROL MODULE (BMS/BECM):SOFTWARE"].head(50)
# Out:
#      Unnamed: 0  RECORD_ID     CAMPNO        MAKETXT            MODELTXT  \
# 113         113     256356  24V475000   SEA ELECTRIC                  5E
# 200         200     261272  24V372000  MERCEDES-BENZ  EQE SUV 500 4MATIC
# 201         201     261273  24V372000  MERCEDES-BENZ  EQE SUV 500 4MATIC
# 202         202     261274  24V372000  MERCEDES-BENZ  EQE SUV 500 4MATIC
# 203         203     261275  24V372000  MERCEDES-BENZ  EQE SUV 500 4MATIC
# 205         205     261277  24V372000  MERCEDES-BENZ  EQE SUV 500 4MATIC
# 206         206     261278  24V372000  MERCEDES-BENZ  EQE SUV 500 4MATIC
# 207         207     261279  24V372000  MERCEDES-BENZ  EQE SUV 500 4MATIC
# 208         208     261280  24V372000  MERCEDES-BENZ  EQE SUV 500 4MATIC
# 209         209     261281  24V372000  MERCEDES-BENZ  EQE SUV 500 4MATIC
# 211         211     261283  24V372000  MERCEDES-BENZ  EQE SUV 500 4MATIC
# 212         212     261284  24V372000  MERCEDES-BENZ  EQE SUV 500 4MATIC
# ...

# %%
subset_2025=df_2025.drop_duplicates(subset='CAMPNO')

# %%
subset_2025.sort_values('POTAFF',ascending=False).head(20)
# Out:
#       Unnamed: 0  RECORD_ID     CAMPNO  MAKETXT               MODELTXT  \
# 9283        9283     322045  26V104000     FORD               F-600 SD
# 1562        1562     287576  24V744000    HONDA                   CR-V
# 9447        9447     323039  26V363000     JEEP              GLADIATOR
# 1979        1979     292219  25V315000     FORD                TRANSIT
# 8836        8836     319749  26V366000    HONDA          ACCORD HYBRID
# 2109        2109     293385  25V744000   TOYOTA                  PRIUS
# 9040        9040     320615  26V124000     FORD                 BRONCO
# 1151        1151     282815  24V763000    HONDA           CIVIC HYBRID
# 1035        1035     282135  24V935000    TESLA                MODEL 3
# 2604        2604     294823  25V595000   TOYOTA    RAV4 PLUG-IN HYBRID
# 4227        4227     301188  25V607000  HYUNDAI               PALISADE
# 9279        9279     322007  26V034000  HYUNDAI               PALISADE
# ...

# %%
subset_2005=df_2005.drop_duplicates(subset='CAMPNO')

# %%
subset_2000=df_2000.drop_duplicates(subset='CAMPNO')

# %%
subset_2020=df_2020.drop_duplicates(subset='CAMPNO')

# %%
subset_2026=df_2026.drop_duplicates(subset='CAMPNO')

# %%
subset_2000=df_2000.drop_duplicates(subset='CAMPNO')
subset_2010=df_2010.drop_duplicates(subset='CAMPNO')
subset_2015=df_2015.drop_duplicates(subset='CAMPNO')

# %%
subset_2005.sort_values('POTAFF',ascending=False).head(10)
# Out:
#       Unnamed: 0  RECORD_ID     CAMPNO    MAKETXT MODELTXT  YEARTXT  \
# 837          837     114901  15V320000      HONDA   ACCORD     2005
# 664          664     103684  14V400000  CHEVROLET   IMPALA     2005
# 890          890     118571  16V352000      DODGE   MAGNUM     2005
# 4497        4497      78604  09V388000     TOYOTA   TACOMA     2005
# 753          753     110224  15V313000      DODGE  DURANGO     2005
# 846          846     115009  15V370000      HONDA   ACCORD     2005
# 713          713     106865  14V355000   CADILLAC  DEVILLE     2005
# 641          641     102734  14V252000  CHEVROLET   MALIBU     2005
# 865          865     116118  16V061000      ACURA       RL     2005
# 251          251      86998  10V017000     TOYOTA   AVALON     2005
#
#                  MFGCAMPNO                                         COMPNAME  \
# 837          JQ9 & JR0-JR8     AIR BAGS:FRONTAL:DRIVER SIDE:INFLATOR MODULE
# ...

# %%
df_2025.groupby('ai_guess')['POTAFF'].mean().sort_values(ascending=False)
# Out:
# ai_guess
# software            706329.070996
# electronics         314522.375736
# chasies             116997.104072
# powertrain          103090.149457
# others               52277.153125
# safety_equipment     37011.782051
# Name: POTAFF, dtype: float64

# %%
df_2025.value_counts('ai_guess')
# Out:
# ai_guess
# software            4620
# electronics         1698
# others              1280
# chasies             1105
# safety_equipment     546
# powertrain           368
# Name: count, dtype: int64

# %%
df_2020.value_counts('ai_guess')
# Out:
# ai_guess
# software            10657
# others               3521
# electronics          2952
# safety_equipment     2308
# powertrain           2097
# chasies              1563
# Name: count, dtype: int64

# %%
df_2026.value_counts('ai_guess')
# Out:
# ai_guess
# software            1046
# electronics          763
# others               545
# safety_equipment     403
# chasies              376
# powertrain           122
# Name: count, dtype: int64

# %%
subset_2025.value_counts('ai_guess')
# Out:
# ai_guess
# others              317
# electronics         211
# chasies             166
# safety_equipment    128
# software            102
# powertrain           88
# Name: count, dtype: int64

# %%
subset_2000.value_counts('ai_guess')
# Out:
# ai_guess
# others              518
# chasies             341
# electronics         230
# safety_equipment    174
# powertrain          122
# software             11
# Name: count, dtype: int64

# %%
subset_2020.value_counts('ai_guess')
# Out:
# ai_guess
# others              564
# electronics         425
# chasies             363
# safety_equipment    293
# powertrain          285
# software            133
# Name: count, dtype: int64

# %%
subset_2026.value_counts('ai_guess')
# Out:
# ai_guess
# others              147
# electronics         108
# safety_equipment     77
# chasies              62
# powertrain           42
# software             39
# Name: count, dtype: int64

# %%
subset_2025.groupby('ai_guess')['POTAFF'].sum().sort_values(ascending=False)
# Out:
# ai_guess
# electronics         13759662
# software             7500707
# others               5165490
# safety_equipment     3112147
# powertrain           3047020
# chasies              3020686
# Name: POTAFF, dtype: int64

# %%
subset_2000.groupby('ai_guess')['POTAFF'].sum().sort_values(ascending=False)
# Out:
# ai_guess
# others              30678810
# electronics         30526819
# chasies             16069923
# powertrain          11594459
# safety_equipment     8173222
# software              550898
# Name: POTAFF, dtype: int64

# %%
subset_2020.groupby('ai_guess')['POTAFF'].sum().sort_values(ascending=False)
# Out:
# ai_guess
# electronics         23819110
# others              17846132
# powertrain          14407661
# software            12757145
# safety_equipment    12177789
# chasies              4440342
# Name: POTAFF, dtype: int64

# %%
data_dir=''
df_2020.to_csv(data_dir + 'Recall_classified2020.csv')

# %%
count_model_2000=df_2000.value_counts('ai_guess').reset_index()
count_model_2005=df_2005.value_counts('ai_guess').reset_index()
count_model_2010=df_2010.value_counts('ai_guess').reset_index()
count_model_2015=df_2015.value_counts('ai_guess').reset_index()
count_model_2020=df_2020.value_counts('ai_guess').reset_index()
count_model_2025=df_2025.value_counts('ai_guess').reset_index()

# %%
count_model=pd.merge(count_model_2000, count_model_2005, on='ai_guess')

# %%
count_model=pd.merge(count_model, count_model_2010, on='ai_guess')

# %%
count_model_2000=count_model_2000.rename(columns={'count': '2000'})
count_model_2005=count_model_2005.rename(columns={'count': '2005'})
count_model_2010=count_model_2010.rename(columns={'count': '2010'})
count_model_2015=count_model_2015.rename(columns={'count': '2015'})
count_model_2020=count_model_2020.rename(columns={'count': '2020'})
count_model_2025=count_model_2025.rename(columns={'count': '2025'})

# %%
count_model_2025
# Out:
#            ai_guess  2025
# 0          software  4620
# 1       electronics  1698
# 2            others  1280
# 3           chasies  1105
# 4  safety_equipment   546
# 5        powertrain   368

# %%
count_model=pd.merge(count_model_2000, count_model_2005, on='ai_guess')
count_model=pd.merge(count_model, count_model_2010, on='ai_guess')
count_model=pd.merge(count_model, count_model_2015, on='ai_guess')
count_model=pd.merge(count_model, count_model_2020, on='ai_guess')
count_model=pd.merge(count_model, count_model_2025, on='ai_guess')
count_model=count_model.rename(columns={'ai_guess': 'group'})

# %%
count_model
# Out:
#               group  2000  2005  2010  2015   2020  2025
# 0            others  1390  1694  1926  2212   3521  1280
# 1           chasies   773   766   687  1193   1563  1105
# 2       electronics   674   652  1098  1196   2952  1698
# 3  safety_equipment   513  1074  2009  1437   2308   546
# 4        powertrain   284   421   607   908   2097   368
# 5          software    32    66   260   445  10657  4620

# %%
count_camp_2000=subset_2000.value_counts('ai_guess').reset_index()
count_camp_2005=subset_2005.value_counts('ai_guess').reset_index()
count_camp_2010=subset_2010.value_counts('ai_guess').reset_index()
count_camp_2015=subset_2015.value_counts('ai_guess').reset_index()
count_camp_2020=subset_2020.value_counts('ai_guess').reset_index()
count_camp_2025=subset_2025.value_counts('ai_guess').reset_index()
count_camp_2000=count_camp_2000.rename(columns={'count': '2000'})
count_camp_2005=count_camp_2005.rename(columns={'count': '2005'})
count_camp_2010=count_camp_2010.rename(columns={'count': '2010'})
count_camp_2015=count_camp_2015.rename(columns={'count': '2015'})
count_camp_2020=count_camp_2020.rename(columns={'count': '2020'})
count_camp_2025=count_camp_2025.rename(columns={'count': '2025'})
count_camp=pd.merge(count_camp_2000, count_camp_2005, on='ai_guess')
count_camp=pd.merge(count_camp, count_camp_2010, on='ai_guess')
count_camp=pd.merge(count_camp, count_camp_2015, on='ai_guess')
count_camp=pd.merge(count_camp, count_camp_2020, on='ai_guess')
count_camp=pd.merge(count_camp, count_camp_2025, on='ai_guess')

# %%
count_model=count_model.transpose()

# %%
count_model.index.name = "group"
count_model.to_csv('count_model.csv', index=True)

# %%
count_model.reset_index()
# Out:
#    index       0        1            2                 3           4         5
# 0  group  others  chasies  electronics  safety_equipment  powertrain  software
# 1   2000    1390      773          674               513         284        32
# 2   2005    1694      766          652              1074         421        66
# 3   2010    1926      687         1098              2009         607       260
# 4   2015    2212     1193         1196              1437         908       445
# 5   2020    3521     1563         2952              2308        2097     10657
# 6   2025    1280     1105         1698               546         368      4620

# %%
count_model.columns = count_model.iloc[0]

# %%
count_model
# Out:
# group others chasies electronics safety_equipment powertrain software    sum
# group
# 2000    1390     773         674              513        284       32   3666
# 2005    1694     766         652             1074        421       66   4673
# 2010    1926     687        1098             2009        607      260   6587
# 2015    2212    1193        1196             1437        908      445   7391
# 2020    3521    1563        2952             2308       2097    10657  23098
# 2025    1280    1105        1698              546        368     4620   9617

# %%
count_model=count_model.drop(index='group')

# %%
count_model["sum"] = count_model[
    ["others", "chasies", "electronics", "safety_equipment", "powertrain", "software"]
].sum(axis=1)
